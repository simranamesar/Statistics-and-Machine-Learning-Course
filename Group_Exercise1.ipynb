# %% [markdown]
# <a href="https://colab.research.google.com/github/simranamesar/Statistics-and-Machine-Learning-Course/blob/main/Group_Exercise1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Group Exercise 1 - Data Preprocessing on a Real Dataset**
#
# **Group Members:**
#
# *   Simran Amesar
# *   Shreya Chowdary Challagulla
# *   Ishwari Thakur
# *   Pooja Chandrappa
# *   Yuvraj Ghag

# %%
import os
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import zscore
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression, Lasso
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ***Loading the Dataset***

# %%
drive_path = "/content/drive/MyDrive/"
file_path = "/content/Statistics_ML_Datasets/healthcare-stroke_dataset.csv"

# Load dataset
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
print("\nShape of dataset:", df.shape)
# Out:
# Shape of dataset: (5110, 12)

# %% [markdown]
# ## **Handling Missing Values**

# %%
print("\nMissing values per column:\n")
print(df.isnull().sum())
# Out:
# Missing values per column:
#
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %% [markdown]
# *Since the **bmi** column contains **201 missing values** and is a numerical feature with outliers, the missing values were imputed using the **median**. The **mean** was avoided as it is sensitive to outliers and could skew the data.*

# %%
bmi_median = df['bmi'].median()
df['bmi'] = df['bmi'].fillna(bmi_median)
print(df.isnull().sum())
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %% [markdown]
# *The missing values in the **bmi** feature were imputed using the **median**, resulting in **zero missing values**.*

# %% [markdown]
# ## **Scaling Numerical Features**

# %% [markdown]
# *We apply Z-score standardization and Min-Max normalization to numerical features.*

# %%
scaler = StandardScaler()
df[['age_z', 'bmi_z', 'avg_glucose_z']] = scaler.fit_transform(
    df[['age', 'bmi', 'avg_glucose_level']]
)

# %%
minmax = MinMaxScaler()
df[['age_mm', 'bmi_mm', 'avg_glucose_mm']] = minmax.fit_transform(
    df[['age', 'bmi', 'avg_glucose_level']]
)

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21  28.1     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke     age_z     bmi_z  avg_glucose_z    age_mm    bmi_mm  \
# 0       1  1.051434  1.005086       2.706375  0.816895  0.301260
# 1       1  0.786070 -0.098981       2.121559  0.743652  0.203895
# 2       1  1.626390  0.472536      -0.005028  0.975586  0.254296
# 3       1  0.255342  0.719327       1.437358  0.597168  0.276060
# 4       1  1.582163 -0.631531       1.501184  0.963379  0.156930
#
#    avg_glucose_mm
# 0        0.801265
# 1        0.679023
# 2        0.234512
# 3        0.536008
# 4        0.549349

# %% [markdown]
# *Z-score standardization and Min–Max normalization were applied to the features **age**, **avg_glucose_level**, and **bmi**, as they are numerical variables. The remaining features are categorical or unique and therefore were not scaled.*

# %% [markdown]
# ## **Handling Noise**

# %%
feature = 'avg_glucose_level'
original_data = df[feature].copy()

# %%
np.random.seed(42)
noise = np.random.normal(0, 15, size=len(df))
noisy_data = original_data + noise

# %%
smoothed_data = pd.Series(noisy_data).rolling(window=5, center=True).mean()

# %%
plt.figure(figsize=(14, 5))

plt.subplot(1, 3, 1)
plt.plot(original_data[:200], label='Original', color='green', linewidth=1.5)
plt.title('Original Data')
plt.xlabel('Index')
plt.ylabel('Glucose Level')
plt.grid(True, alpha=0.3)

plt.subplot(1, 3, 2)
plt.plot(noisy_data[:200], label='With Noise', color='red', linewidth=1.5, alpha=0.7)
plt.title('Data with Noise')
plt.xlabel('Index')
plt.ylabel('Glucose Level')
plt.grid(True, alpha=0.3)

plt.subplot(1, 3, 3)
plt.plot(noisy_data[:200], label='Noisy', color='red', alpha=0.3, linewidth=1)
plt.plot(smoothed_data[:200], label='Smoothed', color='blue', linewidth=2)
plt.title('Before vs After Smoothing')
plt.xlabel('Index')
plt.ylabel('Glucose Level')
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
print(f"Original mean: {original_data.mean():.2f}")
print(f"Noisy mean: {noisy_data.mean():.2f}")
print(f"Smoothed mean: {smoothed_data.mean():.2f}")
print(f"\nOriginal std: {original_data.std():.2f}")
print(f"Noisy std: {noisy_data.std():.2f}")
print(f"Smoothed std: {smoothed_data.std():.2f}")
# Out:
# Original mean: 106.15
# Noisy mean: 106.24
# Smoothed mean: 106.20
#
# Original std: 45.28
# Noisy std: 47.80
# Smoothed std: 22.50

# %% [markdown]
# ## **Handling Outliers**

# %%
df.head(50)
# Out:
#        id  gender   age  hypertension  heart_disease ever_married  \
# 0    9046    Male  67.0             0              1          Yes
# 1   51676  Female  61.0             0              0          Yes
# 2   31112    Male  80.0             0              1          Yes
# 3   60182  Female  49.0             0              0          Yes
# 4    1665  Female  79.0             1              0          Yes
# 5   56669    Male  81.0             0              0          Yes
# 6   53882    Male  74.0             1              1          Yes
# 7   10434  Female  69.0             0              0           No
# 8   27419  Female  59.0             0              0          Yes
# 9   60491  Female  78.0             0              0          Yes
# 10  12109  Female  81.0             1              0          Yes
# 11  12095  Female  61.0             0              1          Yes
# 12  12175  Female  54.0             0              0          Yes
# 13   8213    Male  78.0             0              1          Yes
# 14   5317  Female  79.0             0              1          Yes
# 15  58202  Female  50.0             1              0          Yes
# 16  56112    Male  64.0             0              1          Yes
# 17  34120    Male  75.0             1              0          Yes
# 18  27458  Female  60.0             0              0           No
# 19  25226    Male  57.0             0              1           No
# 20  70630  Female  71.0             0              0          Yes
# 21  13861  Female  52.0             1              0          Yes
# 22  68794  Female  79.0             0              0          Yes
# 23  64778    Male  82.0             0              1          Yes
# 24   4219    Male  71.0             0              0          Yes
# 25  70822    Male  80.0             0              0          Yes
# 26  38047  Female  65.0             0              0          Yes
# 27  61843    Male  58.0             0              0          Yes
# 28  54827    Male  69.0             0              1          Yes
# 29  69160    Male  59.0             0              0          Yes
# 30  43717    Male  57.0             1              0          Yes
# 31  33879    Male  42.0             0              0          Yes
# 32  39373  Female  82.0             1              0          Yes
# 33  54401    Male  80.0             0              1          Yes
# 34  14248    Male  48.0             0              0           No
# 35    712  Female  82.0             1              1           No
# 36  47269    Male  74.0             0              0          Yes
# 37  24977  Female  72.0             1              0          Yes
# 38  47306    Male  58.0             0              0           No
# 39  62602  Female  49.0             0              0          Yes
# 40   4651    Male  78.0             0              0          Yes
# 41   1261    Male  54.0             0              0          Yes
# 42  61960    Male  82.0             0              1          Yes
# 43   1845  Female  63.0             0              0          Yes
# 44   7937    Male  60.0             1              0          Yes
# 45  19824    Male  76.0             1              0          Yes
# 46  37937  Female  75.0             0              1           No
# 47  47472  Female  58.0             0              0          Yes
# 48  35626    Male  81.0             0              0          Yes
# 49  36338  Female  39.0             1              0          Yes
#
#         work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0         Private          Urban             228.69  36.6  formerly smoked
# 1   Self-employed          Rural             202.21  28.1     never smoked
# 2         Private          Rural             105.92  32.5     never smoked
# 3         Private          Urban             171.23  34.4           smokes
# 4   Self-employed          Rural             174.12  24.0     never smoked
# 5         Private          Urban             186.21  29.0  formerly smoked
# 6         Private          Rural              70.09  27.4     never smoked
# 7         Private          Urban              94.39  22.8     never smoked
# 8         Private          Rural              76.15  28.1          Unknown
# 9         Private          Urban              58.57  24.2          Unknown
# 10        Private          Rural              80.43  29.7     never smoked
# 11       Govt_job          Rural             120.46  36.8           smokes
# 12        Private          Urban             104.51  27.3           smokes
# 13        Private          Urban             219.84  28.1          Unknown
# 14        Private          Urban             214.09  28.2     never smoked
# 15  Self-employed          Rural             167.41  30.9     never smoked
# 16        Private          Urban             191.61  37.5           smokes
# 17        Private          Urban             221.29  25.8           smokes
# 18        Private          Urban              89.22  37.8     never smoked
# 19       Govt_job          Urban             217.08  28.1          Unknown
# 20       Govt_job          Rural             193.94  22.4           smokes
# 21  Self-employed          Urban             233.29  48.9     never smoked
# 22  Self-employed          Urban             228.70  26.6     never smoked
# 23        Private          Rural             208.30  32.5          Unknown
# 24        Private          Urban             102.87  27.2  formerly smoked
# 25  Self-employed          Rural             104.12  23.5     never smoked
# 26        Private          Rural             100.98  28.2  formerly smoked
# 27        Private          Rural             189.84  28.1          Unknown
# 28  Self-employed          Urban             195.23  28.3           smokes
# 29        Private          Rural             211.78  28.1  formerly smoked
# 30        Private          Urban             212.08  44.2           smokes
# 31        Private          Rural              83.41  25.4          Unknown
# 32  Self-employed          Urban             196.92  22.2     never smoked
# 33  Self-employed          Urban             252.72  30.5  formerly smoked
# 34       Govt_job          Urban              84.20  29.7     never smoked
# 35        Private          Rural              84.03  26.5  formerly smoked
# 36        Private          Rural             219.72  33.7  formerly smoked
# 37        Private          Rural              74.63  23.1  formerly smoked
# 38        Private          Rural              92.62  32.0          Unknown
# 39        Private          Urban              60.91  29.9     never smoked
# 40        Private          Rural              78.03  23.9  formerly smoked
# 41        Private          Urban              71.22  28.5     never smoked
# 42        Private          Urban             144.90  26.4           smokes
# 43        Private          Urban              90.90  28.1  formerly smoked
# 44       Govt_job          Urban             213.03  20.2           smokes
# 45        Private          Rural             243.58  33.6     never smoked
# 46  Self-employed          Urban             109.78  28.1          Unknown
# 47        Private          Urban             107.26  38.6  formerly smoked
# 48  Self-employed          Urban              99.33  33.7     never smoked
# 49        Private          Rural              58.09  39.2           smokes
#
#     stroke     age_z     bmi_z  avg_glucose_z    age_mm    bmi_mm  \
# 0        1  1.051434  1.005086       2.706375  0.816895  0.301260
# 1        1  0.786070 -0.098981       2.121559  0.743652  0.203895
# 2        1  1.626390  0.472536      -0.005028  0.975586  0.254296
# 3        1  0.255342  0.719327       1.437358  0.597168  0.276060
# 4        1  1.582163 -0.631531       1.501184  0.963379  0.156930
# 5        1  1.670617  0.017920       1.768195  0.987793  0.214204
# 6        1  1.361026 -0.189904      -0.796342  0.902344  0.195876
# 7        1  1.139889 -0.787399      -0.259671  0.841309  0.143184
# 8        1  0.697615 -0.098981      -0.662506  0.719238  0.203895
# 9        1  1.537935 -0.605553      -1.050764  0.951172  0.159221
# 10       1  1.670617  0.108843      -0.567981  0.987793  0.222222
# 11       1  0.786070  1.031064       0.316091  0.743652  0.303551
# 12       1  0.476478 -0.202893      -0.036168  0.658203  0.194731
# 13       1  1.537935 -0.098981       2.510921  0.951172  0.203895
# 14       1  1.582163 -0.085992       2.383931  0.963379  0.205040
# 15       1  0.299569  0.264712       1.352993  0.609375  0.235968
# 16       1  0.918752  1.121987       1.887455  0.780273  0.311569
# 17       1  1.405253 -0.397728       2.542945  0.914551  0.177549
# 18       1  0.741843  1.160954      -0.373852  0.731445  0.315006
# 19       1  0.609161 -0.098981       2.449966  0.694824  0.203895
# 20       1  1.228344 -0.839355       1.938914  0.865723  0.138603
# 21       1  0.388024  2.602736       2.807968  0.633789  0.442153
# 22       1  1.582163 -0.293816       2.706596  0.963379  0.186712
# 23       1  1.714845  0.472536       2.256058  1.000000  0.254296
# 24       1  1.228344 -0.215882      -0.072388  0.865723  0.193585
# 25       1  1.626390 -0.696476      -0.044782  0.975586  0.151203
# 26       1  0.962980 -0.085992      -0.114129  0.792480  0.205040
# 27       1  0.653388 -0.098981       1.848364  0.707031  0.203895
# 28       1  1.139889 -0.073003       1.967404  0.841309  0.206186
# 29       1  0.697615 -0.098981       2.332914  0.719238  0.203895
# 30       1  0.609161  1.992252       2.339540  0.694824  0.388316
# 31       1 -0.054250 -0.449685      -0.502167  0.511719  0.172967
# 32       1  1.714845 -0.865333       2.004728  1.000000  0.136312
# 33       1  1.626390  0.212756       3.237084  0.975586  0.231386
# 34       1  0.211114  0.108843      -0.484720  0.584961  0.222222
# 35       1  1.714845 -0.306805      -0.488474  1.000000  0.185567
# 36       1  1.361026  0.628404       2.508271  0.902344  0.268041
# 37       1  1.272571 -0.748432      -0.696075  0.877930  0.146621
# 38       1  0.653388  0.407591      -0.298762  0.707031  0.248568
# 39       1  0.255342  0.134821      -0.999085  0.597168  0.224513
# 40       1  1.537935 -0.644520      -0.620985  0.951172  0.155785
# 41       1  0.476478 -0.047025      -0.771386  0.658203  0.208477
# 42       1  1.714845 -0.319794       0.855854  1.000000  0.184422
# 43       1  0.874525 -0.098981      -0.336748  0.768066  0.203895
# 44       1  0.741843 -1.125114       2.360521  0.731445  0.113402
# 45       1  1.449481  0.615415       3.035225  0.926758  0.266896
# 46       1  1.405253 -0.098981       0.080221  0.914551  0.203895
# 47       1  0.653388  1.264866       0.024566  0.707031  0.324170
# 48       1  1.670617  0.628404      -0.150570  0.987793  0.268041
# 49       1 -0.186932  1.342801      -1.061365  0.475098  0.331042
#
#     avg_glucose_mm
# 0         0.801265
# 1         0.679023
# 2         0.234512
# 3         0.536008
# 4         0.549349
# 5         0.605161
# 6         0.069107
# 7         0.181285
# 8         0.097082
# 9         0.015927
# 10        0.116841
# 11        0.301634
# 12        0.228003
# 13        0.760410
# 14        0.733866
# 15        0.518373
# 16        0.630090
# 17        0.767104
# 18        0.157419
# 19        0.747669
# 20        0.640846
# 21        0.822500
# 22        0.801311
# 23        0.707137
# 24        0.220432
# 25        0.226203
# 26        0.211707
# 27        0.621919
# 28        0.646801
# 29        0.723202
# 30        0.724587
# 31        0.130597
# 32        0.654603
# 33        0.912196
# 34        0.134244
# 35        0.133460
# 36        0.759856
# 37        0.090066
# 38        0.173114
# 39        0.026729
# 40        0.105761
# 41        0.074324
# 42        0.414458
# 43        0.165174
# 44        0.728972
# 45        0.870003
# 46        0.252331
# 47        0.240698
# 48        0.204090
# 49        0.013711

# %%
A = df['avg_glucose_z']
B = df['age_z']
C = df['bmi_z']

outlier_A = df[abs(A) > 3]
outlier_B = df[abs(B) > 3]
outlier_C = df[abs(C) > 3]

display(outlier_A[['avg_glucose_level']].head())
display(outlier_B[['avg_glucose_level']].head())
display(outlier_C[['avg_glucose_level']].head())
# Out:
#      avg_glucose_level
# 33              252.72
# 45              243.58
# 122             259.63
# 123             249.31
# 135             263.32
# Empty DataFrame
# Columns: [avg_glucose_level]
# Index: []
#      avg_glucose_level
# 113             224.10
# 258             205.84
# 270             129.54
# 333              82.24
# 358              78.40

# %% [markdown]
#  *As we can see there are no outliers in the AGE column.*

# %%
df_after = df[abs(A) <= 3]
df_after = df_after[abs(B) <= 3]
df_after = df_after[abs(C) <= 3]
display(df_after.head(50))
display(df_after.head(115))
# Out:
# /tmp/ipython-input-4237715261.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_after = df_after[abs(B) <= 3]
# /tmp/ipython-input-4237715261.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_after = df_after[abs(C) <= 3]
#        id  gender   age  hypertension  heart_disease ever_married  \
# 0    9046    Male  67.0             0              1          Yes
# 1   51676  Female  61.0             0              0          Yes
# 2   31112    Male  80.0             0              1          Yes
# 3   60182  Female  49.0             0              0          Yes
# 4    1665  Female  79.0             1              0          Yes
# 5   56669    Male  81.0             0              0          Yes
# 6   53882    Male  74.0             1              1          Yes
# 7   10434  Female  69.0             0              0           No
# 8   27419  Female  59.0             0              0          Yes
# 9   60491  Female  78.0             0              0          Yes
# 10  12109  Female  81.0             1              0          Yes
# 11  12095  Female  61.0             0              1          Yes
# 12  12175  Female  54.0             0              0          Yes
# 13   8213    Male  78.0             0              1          Yes
# 14   5317  Female  79.0             0              1          Yes
# 15  58202  Female  50.0             1              0          Yes
# 16  56112    Male  64.0             0              1          Yes
# 17  34120    Male  75.0             1              0          Yes
# 18  27458  Female  60.0             0              0           No
# 19  25226    Male  57.0             0              1           No
# 20  70630  Female  71.0             0              0          Yes
# 21  13861  Female  52.0             1              0          Yes
# 22  68794  Female  79.0             0              0          Yes
# 23  64778    Male  82.0             0              1          Yes
# 24   4219    Male  71.0             0              0          Yes
# 25  70822    Male  80.0             0              0          Yes
# 26  38047  Female  65.0             0              0          Yes
# 27  61843    Male  58.0             0              0          Yes
# 28  54827    Male  69.0             0              1          Yes
# 29  69160    Male  59.0             0              0          Yes
# 30  43717    Male  57.0             1              0          Yes
# 31  33879    Male  42.0             0              0          Yes
# 32  39373  Female  82.0             1              0          Yes
# 34  14248    Male  48.0             0              0           No
# 35    712  Female  82.0             1              1           No
# 36  47269    Male  74.0             0              0          Yes
# 37  24977  Female  72.0             1              0          Yes
# 38  47306    Male  58.0             0              0           No
# 39  62602  Female  49.0             0              0          Yes
# 40   4651    Male  78.0             0              0          Yes
# 41   1261    Male  54.0             0              0          Yes
# 42  61960    Male  82.0             0              1          Yes
# 43   1845  Female  63.0             0              0          Yes
# 44   7937    Male  60.0             1              0          Yes
# 46  37937  Female  75.0             0              1           No
# 47  47472  Female  58.0             0              0          Yes
# 48  35626    Male  81.0             0              0          Yes
# 49  36338  Female  39.0             1              0          Yes
# 50  18587  Female  76.0             0              0           No
# 51  15102    Male  78.0             1              0          Yes
#
#         work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0         Private          Urban             228.69  36.6  formerly smoked
# 1   Self-employed          Rural             202.21  28.1     never smoked
# 2         Private          Rural             105.92  32.5     never smoked
# 3         Private          Urban             171.23  34.4           smokes
# 4   Self-employed          Rural             174.12  24.0     never smoked
# 5         Private          Urban             186.21  29.0  formerly smoked
# 6         Private          Rural              70.09  27.4     never smoked
# 7         Private          Urban              94.39  22.8     never smoked
# 8         Private          Rural              76.15  28.1          Unknown
# 9         Private          Urban              58.57  24.2          Unknown
# 10        Private          Rural              80.43  29.7     never smoked
# 11       Govt_job          Rural             120.46  36.8           smokes
# 12        Private          Urban             104.51  27.3           smokes
# 13        Private          Urban             219.84  28.1          Unknown
# 14        Private          Urban             214.09  28.2     never smoked
# 15  Self-employed          Rural             167.41  30.9     never smoked
# 16        Private          Urban             191.61  37.5           smokes
# 17        Private          Urban             221.29  25.8           smokes
# 18        Private          Urban              89.22  37.8     never smoked
# 19       Govt_job          Urban             217.08  28.1          Unknown
# 20       Govt_job          Rural             193.94  22.4           smokes
# 21  Self-employed          Urban             233.29  48.9     never smoked
# 22  Self-employed          Urban             228.70  26.6     never smoked
# 23        Private          Rural             208.30  32.5          Unknown
# 24        Private          Urban             102.87  27.2  formerly smoked
# 25  Self-employed          Rural             104.12  23.5     never smoked
# 26        Private          Rural             100.98  28.2  formerly smoked
# 27        Private          Rural             189.84  28.1          Unknown
# 28  Self-employed          Urban             195.23  28.3           smokes
# 29        Private          Rural             211.78  28.1  formerly smoked
# 30        Private          Urban             212.08  44.2           smokes
# 31        Private          Rural              83.41  25.4          Unknown
# 32  Self-employed          Urban             196.92  22.2     never smoked
# 34       Govt_job          Urban              84.20  29.7     never smoked
# 35        Private          Rural              84.03  26.5  formerly smoked
# 36        Private          Rural             219.72  33.7  formerly smoked
# 37        Private          Rural              74.63  23.1  formerly smoked
# 38        Private          Rural              92.62  32.0          Unknown
# 39        Private          Urban              60.91  29.9     never smoked
# 40        Private          Rural              78.03  23.9  formerly smoked
# 41        Private          Urban              71.22  28.5     never smoked
# 42        Private          Urban             144.90  26.4           smokes
# 43        Private          Urban              90.90  28.1  formerly smoked
# 44       Govt_job          Urban             213.03  20.2           smokes
# 46  Self-employed          Urban             109.78  28.1          Unknown
# 47        Private          Urban             107.26  38.6  formerly smoked
# 48  Self-employed          Urban              99.33  33.7     never smoked
# 49        Private          Rural              58.09  39.2           smokes
# 50        Private          Urban              89.96  28.1          Unknown
# 51        Private          Urban              75.32  28.1  formerly smoked
#
#     stroke     age_z     bmi_z  avg_glucose_z    age_mm    bmi_mm  \
# 0        1  1.051434  1.005086       2.706375  0.816895  0.301260
# 1        1  0.786070 -0.098981       2.121559  0.743652  0.203895
# 2        1  1.626390  0.472536      -0.005028  0.975586  0.254296
# 3        1  0.255342  0.719327       1.437358  0.597168  0.276060
# 4        1  1.582163 -0.631531       1.501184  0.963379  0.156930
# 5        1  1.670617  0.017920       1.768195  0.987793  0.214204
# 6        1  1.361026 -0.189904      -0.796342  0.902344  0.195876
# 7        1  1.139889 -0.787399      -0.259671  0.841309  0.143184
# 8        1  0.697615 -0.098981      -0.662506  0.719238  0.203895
# 9        1  1.537935 -0.605553      -1.050764  0.951172  0.159221
# 10       1  1.670617  0.108843      -0.567981  0.987793  0.222222
# 11       1  0.786070  1.031064       0.316091  0.743652  0.303551
# 12       1  0.476478 -0.202893      -0.036168  0.658203  0.194731
# 13       1  1.537935 -0.098981       2.510921  0.951172  0.203895
# 14       1  1.582163 -0.085992       2.383931  0.963379  0.205040
# 15       1  0.299569  0.264712       1.352993  0.609375  0.235968
# 16       1  0.918752  1.121987       1.887455  0.780273  0.311569
# 17       1  1.405253 -0.397728       2.542945  0.914551  0.177549
# 18       1  0.741843  1.160954      -0.373852  0.731445  0.315006
# 19       1  0.609161 -0.098981       2.449966  0.694824  0.203895
# 20       1  1.228344 -0.839355       1.938914  0.865723  0.138603
# 21       1  0.388024  2.602736       2.807968  0.633789  0.442153
# 22       1  1.582163 -0.293816       2.706596  0.963379  0.186712
# 23       1  1.714845  0.472536       2.256058  1.000000  0.254296
# 24       1  1.228344 -0.215882      -0.072388  0.865723  0.193585
# 25       1  1.626390 -0.696476      -0.044782  0.975586  0.151203
# 26       1  0.962980 -0.085992      -0.114129  0.792480  0.205040
# 27       1  0.653388 -0.098981       1.848364  0.707031  0.203895
# 28       1  1.139889 -0.073003       1.967404  0.841309  0.206186
# 29       1  0.697615 -0.098981       2.332914  0.719238  0.203895
# 30       1  0.609161  1.992252       2.339540  0.694824  0.388316
# 31       1 -0.054250 -0.449685      -0.502167  0.511719  0.172967
# 32       1  1.714845 -0.865333       2.004728  1.000000  0.136312
# 34       1  0.211114  0.108843      -0.484720  0.584961  0.222222
# 35       1  1.714845 -0.306805      -0.488474  1.000000  0.185567
# 36       1  1.361026  0.628404       2.508271  0.902344  0.268041
# 37       1  1.272571 -0.748432      -0.696075  0.877930  0.146621
# 38       1  0.653388  0.407591      -0.298762  0.707031  0.248568
# 39       1  0.255342  0.134821      -0.999085  0.597168  0.224513
# 40       1  1.537935 -0.644520      -0.620985  0.951172  0.155785
# 41       1  0.476478 -0.047025      -0.771386  0.658203  0.208477
# 42       1  1.714845 -0.319794       0.855854  1.000000  0.184422
# 43       1  0.874525 -0.098981      -0.336748  0.768066  0.203895
# 44       1  0.741843 -1.125114       2.360521  0.731445  0.113402
# 46       1  1.405253 -0.098981       0.080221  0.914551  0.203895
# 47       1  0.653388  1.264866       0.024566  0.707031  0.324170
# 48       1  1.670617  0.628404      -0.150570  0.987793  0.268041
# 49       1 -0.186932  1.342801      -1.061365  0.475098  0.331042
# 50       1  1.449481 -0.098981      -0.357509  0.926758  0.203895
# 51       1  1.537935 -0.098981      -0.680836  0.951172  0.203895
#
#     avg_glucose_mm
# 0         0.801265
# 1         0.679023
# 2         0.234512
# 3         0.536008
# 4         0.549349
# 5         0.605161
# 6         0.069107
# 7         0.181285
# 8         0.097082
# 9         0.015927
# 10        0.116841
# 11        0.301634
# 12        0.228003
# 13        0.760410
# 14        0.733866
# 15        0.518373
# 16        0.630090
# 17        0.767104
# 18        0.157419
# 19        0.747669
# 20        0.640846
# 21        0.822500
# 22        0.801311
# 23        0.707137
# 24        0.220432
# 25        0.226203
# 26        0.211707
# 27        0.621919
# 28        0.646801
# 29        0.723202
# 30        0.724587
# 31        0.130597
# 32        0.654603
# 34        0.134244
# 35        0.133460
# 36        0.759856
# 37        0.090066
# 38        0.173114
# 39        0.026729
# 40        0.105761
# 41        0.074324
# 42        0.414458
# 43        0.165174
# 44        0.728972
# 46        0.252331
# 47        0.240698
# 48        0.204090
# 49        0.013711
# 50        0.160835
# 51        0.093251
#         id  gender   age  hypertension  heart_disease ever_married  \
# 0     9046    Male  67.0             0              1          Yes
# 1    51676  Female  61.0             0              0          Yes
# 2    31112    Male  80.0             0              1          Yes
# 3    60182  Female  49.0             0              0          Yes
# 4     1665  Female  79.0             1              0          Yes
# ..     ...     ...   ...           ...            ...          ...
# 112  36706  Female  76.0             0              0          Yes
# 114  71639  Female  68.0             0              0           No
# 115  53401    Male  71.0             1              1           No
# 116  60744    Male  61.0             1              0          Yes
# 117   7547    Male  74.0             0              0          Yes
#
#          work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0          Private          Urban             228.69  36.6  formerly smoked
# 1    Self-employed          Rural             202.21  28.1     never smoked
# 2          Private          Rural             105.92  32.5     never smoked
# 3          Private          Urban             171.23  34.4           smokes
# 4    Self-employed          Rural             174.12  24.0     never smoked
# ..             ...            ...                ...   ...              ...
# 112  Self-employed          Urban             106.41  28.1  formerly smoked
# 114       Govt_job          Urban              82.10  27.1          Unknown
# 115       Govt_job          Rural             216.94  30.9     never smoked
# 116  Self-employed          Rural              76.11  27.3           smokes
# 117        Private          Urban              72.96  31.3           smokes
#
#      stroke     age_z     bmi_z  avg_glucose_z    age_mm    bmi_mm  \
# 0         1  1.051434  1.005086       2.706375  0.816895  0.301260
# 1         1  0.786070 -0.098981       2.121559  0.743652  0.203895
# 2         1  1.626390  0.472536      -0.005028  0.975586  0.254296
# 3         1  0.255342  0.719327       1.437358  0.597168  0.276060
# 4         1  1.582163 -0.631531       1.501184  0.963379  0.156930
# ..      ...       ...       ...            ...       ...       ...
# 112       1  1.449481 -0.098981       0.005793  0.926758  0.203895
# 114       1  1.095662 -0.228871      -0.531098  0.829102  0.192440
# 115       1  1.228344  0.264712       2.446874  0.865723  0.235968
# 116       1  0.786070 -0.202893      -0.663389  0.743652  0.194731
# 117       1  1.361026  0.316668      -0.732957  0.902344  0.240550
#
#      avg_glucose_mm
# 0          0.801265
# 1          0.679023
# 2          0.234512
# 3          0.536008
# 4          0.549349
# ..              ...
# 112        0.236774
# 114        0.124550
# 115        0.747022
# 116        0.096898
# 117        0.082356
#
# [115 rows x 18 columns]

# %% [markdown]
# *Outliers were removed rather than transformed because extreme values could disproportionately bias the model, and their removal improved data consistency, reduced skewness, and enhanced overall model performance.*

# %% [markdown]
# ## **Feature Selection**

# %% [markdown]
# **Correlation**

# %%
df[['age', 'bmi', 'avg_glucose_level']].corr()
# Out:
#                         age       bmi  avg_glucose_level
# age                1.000000  0.324296           0.238171
# bmi                0.324296  1.000000           0.166876
# avg_glucose_level  0.238171  0.166876           1.000000

# %% [markdown]
# *Selected the columns age, bmi, and avg_glucose_level from the dataset and computes the correlation between them.
# The result shows how strongly each pair of variables is related, with values.*

# %% [markdown]
# **Regression**

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

X = df[['age', 'bmi', 'avg_glucose_level']]
y = df['stroke']

model = LinearRegression()
rfe = RFE(model, n_features_to_select=1)
rfe.fit(X, y)

pd.DataFrame({'Feature': X.columns, 'Selected': rfe.support_})
# Out:
#              Feature  Selected
# 0                age      True
# 1                bmi     False
# 2  avg_glucose_level     False

# %% [markdown]
# *To identify the most important feature for predicting stroke.*

# %% [markdown]
# **Lasso Regression**

# %%
from sklearn.linear_model import Lasso

lasso = Lasso(alpha=0.1)
lasso.fit(X, y)

pd.DataFrame({'Feature': X.columns, 'Coefficient': lasso.coef_})
# Out:
#              Feature  Coefficient
# 0                age     0.001976
# 1                bmi    -0.000000
# 2  avg_glucose_level     0.000344

# %% [markdown]
# *To shrink less important feature coefficients toward zero.*
